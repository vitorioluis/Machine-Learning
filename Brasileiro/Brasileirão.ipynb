# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")

# %%
df = pd.read_csv('Tabelas/Tabela_Clubes.csv',sep=';')

# %%
df.head()
# Out:
#     Ano  Pos.        Clubes  Vitorias  Empates  Derrotas   GolsF/S  Saldo  \
# 0  2018    18    America-MG        10       10        18  30:47:00    -17
# 1  2018     7  Athletico-PR        16        9        13  54:37:00     17
# 2  2018     6   Atletico-MG        17        8        13  56:43:00     13
# 3  2018    11         Bahia        12       12        14  39:41:00     -2
# 4  2018     9      Botafogo        13       12        13  38:46:00     -8
#
#    Qtd_Jogadores Idade_Media  Estrangeiros  Valor_total  Media_Valor
# 0             51        24,8             0     27350000       536000
# 1             52          24             3     37650000       724000
# 2             50        23,4             6     61350000      1230000
# 3             48        23,2             2     34900000       727000
# 4             45        23,1             4     25550000       568000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 13 columns):
# Ano              200 non-null int64
# Pos.             200 non-null int64
# Clubes           200 non-null object
# Vitorias         200 non-null int64
# Empates          200 non-null int64
# Derrotas         200 non-null int64
# GolsF/S          200 non-null object
# Saldo            200 non-null int64
# Qtd_Jogadores    200 non-null int64
# Idade_Media      200 non-null object
# Estrangeiros     200 non-null int64
# Valor_total      200 non-null int64
# Media_Valor      200 non-null int64
# dtypes: int64(10), object(3)
# memory usage: 20.4+ KB

# %%
df.Saldo.describe()
# Out:
# count    200.00000
# mean       0.00000
# std       15.52725
# min      -57.00000
# 25%       -9.00000
# 50%       -1.00000
# 75%       11.25000
# max       40.00000
# Name: Saldo, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="Ano", y="Saldo", data=df);

# %%
df['pontos'] = df.Vitorias * 3 + df.Empates

# %%
df_campeao = df[df['Pos.'] == 1]

# %%
sns.scatterplot(x= df_campeao.Saldo, y=df_campeao.pontos, hue=df_campeao.Clubes);

# %%
plt.figure(figsize=(15,5))
plt.scatter(x = df['Saldo'], y=df['pontos'], alpha=0.4, c=df['Ano'], s=df['pontos']**1.5);

# %%
df.pontos.hist(bins=10);
